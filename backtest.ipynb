# %%
import pandas as pd
import numpy as np
from pathlib import Path
from dataclasses import dataclass
import logging
from typing import Dict, Optional, Protocol, Tuple
from scipy import stats
from new_strategy import TradingStrategy, Asset, BetSizingMethod, get_bet_sizing
import new_strategy
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
@dataclass
class ReturnMetrics:
    """Performance metrics for strategy evaluation"""
    total_pnl: float
    total_return_pct: float
    win_rate: float
    avg_win: float
    avg_loss: float
    sharpe: Optional[float]
    skewness: Optional[float]
    excess_kurtosis: Optional[float]
    max_drawdown_pct: float
    total_trades: int
    risk_amount: float

class Backtest:
    def __init__(self, strategy, output_dir: Path = None):
        self.strategy = strategy
        self.trades_df = strategy.get_trade_data()
        self.output_dir = output_dir or Path("data/results")
        self.output_dir.mkdir(parents=True, exist_ok=True)
        self.results = {}

        self.logger = logging.getLogger(__name__)
        if not self.logger.handlers:
            logging.basicConfig(
                level=logging.INFO,
                format='%(asctime)s - %(levelname)s - %(message)s'
            )


    def _calculate_performance_metrics(self, sharpe_returns: pd.Series, full_returns: pd.Series) -> Tuple[float, float, float]:
        """
        Calculate Sharpe (from trading days) and skewness/kurtosis (from full daily returns).

        Args:
            sharpe_returns (pd.Series): Returns on actual trading days only (no forward fill).
            full_returns (pd.Series): Full daily returns (with forward fill).

        Returns:
            (sharpe, skewness, excess_kurtosis)
        """
        sharpe_returns = sharpe_returns.dropna()
        full_returns = full_returns.dropna()

        # Sharpe: only on trading days
        if len(sharpe_returns) >= 2:
            mean_return = sharpe_returns.mean()
            vol = sharpe_returns.std()
            sharpe = (mean_return / vol) * np.sqrt(252) if vol != 0 else np.nan
        else:
            sharpe = np.nan

        # Skewness & kurtosis: on trading days
        if len(full_returns) >= 2:
            skewness = stats.skew(sharpe_returns, nan_policy='omit')
            excess_kurtosis = stats.kurtosis(sharpe_returns, fisher=True, nan_policy='omit')
        else:
            skewness = np.nan
            excess_kurtosis = np.nan

        return sharpe, skewness, excess_kurtosis


    def _calculate_drawdown(self, returns: pd.Series) -> float:
        cum_returns = (1 + returns).cumprod()
        rolling_max = cum_returns.expanding().max()
        drawdowns = (cum_returns - rolling_max) / rolling_max
        return abs(drawdowns.min()) * 100

    def _calculate_return_metrics(self, trades_df: pd.DataFrame) -> Tuple[ReturnMetrics, pd.DataFrame]:
        """
        Calculate metrics based on capital growth curve and update capital_curve column.
        """
        if trades_df.empty:
            return ReturnMetrics(0, 0, 0, 0, 0, np.nan, np.nan, np.nan, 0, 0, 0), trades_df

        #Filter Trades that are 0
        trades_df = trades_df[trades_df['position_size'] > 0]

        # Sort trades by exit time to maintain order
        trades_df = trades_df.sort_values('exit_time')
        capital = self.strategy.INITIAL_CAPITAL
        capital_curve = []

        # Build capital curve on trade exits
        for _, trade in trades_df.iterrows():
            capital += trade['pnl']
            capital_curve.append(capital)

        trades_df = trades_df.copy()
        trades_df['capital_curve'] = capital_curve

        # Capital curve: trading days only (no forward fill)
        capital_curve_series = trades_df.set_index('exit_time')['capital_curve'].sort_index()
        returns_on_trading_days = capital_curve_series.pct_change().dropna()

        # Full daily capital curve (with forward fill for skew/kurtosis)
        capital_df = trades_df[['exit_time', 'capital_curve']].copy()
        capital_df['date'] = capital_df['exit_time'].dt.date
        daily_capital = capital_df.groupby('date')['capital_curve'].last()

        full_date_range = pd.date_range(daily_capital.index.min(), daily_capital.index.max(), freq='D')
        daily_capital_filled = daily_capital.reindex(full_date_range).ffill()
        returns_full = daily_capital_filled.pct_change().dropna()

        # Calculate performance metrics
        sharpe, skewness, excess_kurtosis = self._calculate_performance_metrics(
            sharpe_returns=returns_on_trading_days,
            full_returns=returns_full
        )

        # Basic metrics
        winning_trades = trades_df[trades_df['pnl'] > 0]
        losing_trades = trades_df[trades_df['pnl'] < 0]
        total_pnl = trades_df['pnl'].sum()
        initial_capital = self.strategy.INITIAL_CAPITAL

        return ReturnMetrics(
            total_pnl=total_pnl,
            total_return_pct=((capital - initial_capital) / initial_capital) * 100,
            win_rate=len(winning_trades) / len(trades_df),
            avg_win=winning_trades['pnl'].mean() if not winning_trades.empty else 0,
            avg_loss=losing_trades['pnl'].mean() if not losing_trades.empty else 0,
            sharpe=sharpe,
            skewness=skewness,
            excess_kurtosis=excess_kurtosis,
            max_drawdown_pct=self._calculate_drawdown(returns_full),
            total_trades=len(trades_df),
            risk_amount=trades_df['risk_amount'].iloc[0] if 'risk_amount' in trades_df.columns else 0
        ), trades_df


    def _export_detailed_trades(self) -> None:
        bet_sizing_name = self.strategy.bet_sizing_method.value
        filename = f"trades_detailed_{self.strategy.asset.value}_{bet_sizing_name}.csv"
        output_path = self.output_dir / filename
        self.trades_df.sort_values('entry_time').to_csv(output_path, index=False)
        self.logger.info(f"Exported detailed trades to {output_path}")


    def save_results_to_file(self) -> None:
        """Save backtest results to a text file (no fee, includes bet sizing method)"""
        bet_sizing_name = self.strategy.bet_sizing_method.value
        filename = f"backtest_results_{self.strategy.asset.value}_{bet_sizing_name}.txt"
        output_path = self.output_dir / filename

        with open(output_path, 'w') as f:
            f.write(f"=== {self.strategy.asset.value} Backtest Results ===\n")
            f.write(f"Bet Sizing Strategy: {bet_sizing_name}\n\n")

            if self.results['period']['start'] is not None:
                f.write(f"Period: {self.results['period']['start']:%Y-%m-%d} to {self.results['period']['end']:%Y-%m-%d}\n\n")

            for session, data in self.results['sessions'].items():
                metrics = data['metrics']
                f.write(f"\n{session.upper()} Session Performance:\n")
                f.write(f"Initial Capital: ${self.strategy.INITIAL_CAPITAL:,.2f}\n")
                f.write(f"Final Capital: ${(self.strategy.INITIAL_CAPITAL * (1 + metrics.total_return_pct/100)):,.2f}\n")
                f.write(f"Total PnL: ${metrics.total_pnl:,.2f}\n")
                f.write(f"Return: {metrics.total_return_pct:.2f}%\n")

                session_trades = self.trades_df[self.trades_df['session'] == session]
                wins = len(session_trades[session_trades['pnl'] > 0])
                losses = len(session_trades[session_trades['pnl'] <= 0])
                f.write(f"Win Rate: {metrics.win_rate:.2%} ({wins}W/{losses}L)\n")
                f.write(f"Max Drawdown: {metrics.max_drawdown_pct:.2f}%\n")

                if metrics.sharpe is not None:
                    f.write(f"Sharpe Ratio: {metrics.sharpe:.2f}\n")
                if metrics.skewness is not None:
                    f.write(f"Skewness: {metrics.skewness:.3f}\n")
                if metrics.excess_kurtosis is not None:
                    f.write(f"Excess Kurtosis: {metrics.excess_kurtosis:.3f}\n")

                # Write attempt analysis
                if data['attempts']:
                    f.write("\nAttempt Analysis:\n")
                    for attempt, attempt_metrics in data['attempts'].items():
                        attempt_trades = session_trades[session_trades['attempt'] == attempt]
                        wins = len(attempt_trades[attempt_trades['pnl'] > 0])
                        losses = len(attempt_trades[attempt_trades['pnl'] <= 0])

                        f.write(f"\n  Attempt {attempt}:\n")
                        f.write(f"  Trades: {attempt_metrics.total_trades} "
                                f"({attempt_metrics.total_trades/metrics.total_trades*100:.1f}% of session trades)\n")
                        f.write(f"  PnL: ${attempt_metrics.total_pnl:,.2f}\n")
                        f.write(f"  Win Rate: {attempt_metrics.win_rate:.2%} ({wins}W/{losses}L)\n")
                        f.write(f"  Average Win: ${attempt_metrics.avg_win:,.2f}\n")
                        f.write(f"  Average Loss: ${attempt_metrics.avg_loss:,.2f}\n")

            f.write("\n" + "="*50 + "\n")

        self.logger.info(f"Saved backtest results to {output_path}")


    def run_analysis(self) -> None:
        if self.trades_df is None or self.trades_df.empty:
            self.logger.warning(f"No trades generated for {self.strategy.asset.value}")
            self.results = {
                'asset': self.strategy.asset.value,
                'sessions': {},
                'period': {'start': None, 'end': None}
            }
            return

        # Initialize results structure
        self.results = {
            'asset': self.strategy.asset.value,
            'sessions': {},
            'period': {
                'start': self.trades_df['entry_time'].min(),
                'end': self.trades_df['entry_time'].max()
            }
        }

        for session in ['asian', 'london', 'us']:
            session_trades = self.trades_df[self.trades_df['session'] == session]

            if session_trades.empty:
                self.logger.debug(f"No trades for {session} session in {self.strategy.asset.value}")
                continue

            session_metrics, updated_trades = self._calculate_return_metrics(session_trades)

            # Update main trades_df with the capital curve for that session
            self.trades_df.loc[updated_trades.index, 'capital_curve'] = updated_trades['capital_curve']

            attempt_metrics = {}
            for attempt in sorted(session_trades['attempt'].unique()):
                attempt_trades = session_trades[session_trades['attempt'] == attempt]
                metrics, _ = self._calculate_return_metrics(attempt_trades)
                attempt_metrics[attempt] = metrics

            self.results['sessions'][session] = {
                'metrics': session_metrics,
                'attempts': attempt_metrics
            }

        # Export after all sessions processed
        self._export_detailed_trades()
        self.save_results_to_file()

    def print_summary(self) -> None:
        """Print comprehensive analysis summary (no fee, includes bet sizing)"""
        if not self.results:
            self.logger.warning("No results available for analysis")
            return

        bet_sizing_name = type(self.strategy.bet_sizing).__name__.lower()

        print(f"\n=== {self.strategy.asset.value} Backtest Results ===")
        print(f"Bet Sizing Strategy: {bet_sizing_name}\n")

        if not self.results['sessions']:
            print("No trades were generated during the test period.")
            return

        if self.results['period']['start'] is not None:
            print(f"Period: {self.results['period']['start']:%Y-%m-%d} to {self.results['period']['end']:%Y-%m-%d}")

        for session, data in self.results['sessions'].items():
            metrics = data['metrics']
            print(f"\n{session.upper()} Session Performance:")
            print(f"Initial Capital: ${self.strategy.INITIAL_CAPITAL:,.2f}")
            print(f"Final Capital: ${(self.strategy.INITIAL_CAPITAL * (1 + metrics.total_return_pct / 100)):,.2f}")
            print(f"Total PnL: ${metrics.total_pnl:,.2f}")
            print(f"Return: {metrics.total_return_pct:.2f}%")

            session_trades = self.trades_df[self.trades_df['session'] == session]
            wins = len(session_trades[session_trades['pnl'] > 0])
            losses = len(session_trades[session_trades['pnl'] <= 0])
            print(f"Win Rate: {metrics.win_rate:.2%} ({wins}W/{losses}L)")
            print(f"Max Drawdown: {metrics.max_drawdown_pct:.2f}%")

            if metrics.sharpe is not None:
                print(f"Sharpe Ratio: {metrics.sharpe:.2f}")
            if metrics.skewness is not None:
                print(f"Skewness: {metrics.skewness:.3f}")
            if metrics.excess_kurtosis is not None:
                print(f"Excess Kurtosis: {metrics.excess_kurtosis:.3f}")

            if data['attempts']:
                print("\nAttempt Analysis:")
                for attempt, attempt_metrics in data['attempts'].items():
                    attempt_trades = session_trades[session_trades['attempt'] == attempt]
                    wins = len(attempt_trades[attempt_trades['pnl'] > 0])
                    losses = len(attempt_trades[attempt_trades['pnl'] <= 0])

                    print(f"\n  Attempt {attempt}:")
                    print(f"  Trades: {attempt_metrics.total_trades} "
                        f"({attempt_metrics.total_trades / metrics.total_trades * 100:.1f}% of session trades)")
                    print(f"  PnL: ${attempt_metrics.total_pnl:,.2f}")
                    print(f"  Win Rate: {attempt_metrics.win_rate:.2%} ({wins}W/{losses}L)")
                    print(f"  Average Win: ${attempt_metrics.avg_win:,.2f}")
                    print(f"  Average Loss: ${attempt_metrics.avg_loss:,.2f}")
      

BET_SIZING_MODE = BetSizingMethod.OPTIMAL_F

def main():
    """
    Run backtest with the updated trading strategy and zero trading fees.
    """
    from new_strategy import TradingStrategy
    from pathlib import Path
    import logging

    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )
    logger = logging.getLogger(__name__)

    assets = ["XAUUSD"]

    output_dir = Path("data/results")
    output_dir.mkdir(parents=True, exist_ok=True)

    for asset_name in assets:
        try:
            data_path = Path(f"data/processed/{asset_name}/combined_data.csv")
            if not data_path.exists():
                logger.warning(f"Data file not found for {asset_name}, skipping...")
                continue

            data = pd.read_csv(data_path, index_col='timestamp', parse_dates=True)

            logger.info(f"\nRunning backtest for {asset_name} with no fees")

           
            past_returns = data['close'].pct_change().dropna()
            bet_sizing = get_bet_sizing(BET_SIZING_MODE, past_returns=past_returns)

            strategy = TradingStrategy(data, asset_name, bet_sizing, BET_SIZING_MODE)
            strategy.generate_signals()
            strategy.simulate_trades()

            backtest = Backtest(strategy, output_dir)
            backtest.run_analysis()
            backtest.print_summary()
            #If KellyBetSizing is used, print how many times the cap was hit
            if hasattr(strategy.bet_sizing, "report_limit_hits"):
                 strategy.bet_sizing.report_limit_hits()
            if hasattr(strategy.bet_sizing, "limit_hit_counter"):
                print(f"[INFO] PercentVolatilityBetSizing limit hit {strategy.bet_sizing.limit_hit_counter} times.")

        except Exception as e:
            logger.error(f"Error testing {asset_name}: {str(e)}", exc_info=True)

if __name__ == "__main__":
    main()
# Out:
# 2025-05-12 16:27:06,456 - INFO -
# Running backtest for XAUUSD with no fees
# 2025-05-12 16:27:06,540 - INFO - Strategy initialized for XAUUSD using OptimalF
# [OptimalF] Session: asian, available trades: 0/20
# [OptimalF] (Default) session=asian, equity=100000.00, price=1518.71, risk=0.0100, risk_amount=1000.00
# [OptimalF] Trade added: session=asian, pnl=0.17, total_trades=1
# [OptimalF] Session: london, available trades: 0/20
# [OptimalF] (Default) session=london, equity=100000.00, price=1518.97, risk=0.0100, risk_amount=1000.00
# [OptimalF] Trade added: session=london, pnl=5.00, total_trades=1
# [OptimalF] Session: us, available trades: 0/20
# [OptimalF] (Default) session=us, equity=100000.00, price=1523.28, risk=0.0100, risk_amount=1000.00
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=1
# [OptimalF] Session: asian, available trades: 1/20
# [OptimalF] (Default) session=asian, equity=100000.17, price=1529.16, risk=0.0100, risk_amount=1000.00
# [OptimalF] Trade added: session=asian, pnl=5.00, total_trades=2
# [OptimalF] Session: london, available trades: 1/20
# [OptimalF] (Default) session=london, equity=100005.00, price=1545.04, risk=0.0100, risk_amount=1000.05
# [OptimalF] Trade added: session=london, pnl=2.57, total_trades=2
# [OptimalF] Session: us, available trades: 1/20
# [OptimalF] (Default) session=us, equity=100005.00, price=1546.21, risk=0.0100, risk_amount=1000.05
# [OptimalF] Trade added: session=us, pnl=1.67, total_trades=2
# [OptimalF] Session: asian, available trades: 2/20
# [OptimalF] (Default) session=asian, equity=100005.17, price=1568.42, risk=0.0100, risk_amount=1000.05
# [OptimalF] Trade added: session=asian, pnl=5.00, total_trades=3
# [OptimalF] Session: london, available trades: 2/20
# [OptimalF] (Default) session=london, equity=100007.57, price=1572.26, risk=0.0100, risk_amount=1000.08
# [OptimalF] Trade added: session=london, pnl=-5.00, total_trades=3
# [OptimalF] Session: london, available trades: 3/20
# [OptimalF] (Default) session=london, equity=100002.57, price=1564.39, risk=0.0100, risk_amount=1000.03
# [OptimalF] Trade added: session=london, pnl=-0.28, total_trades=4
# [OptimalF] Session: us, available trades: 2/20
# [OptimalF] (Default) session=us, equity=100006.67, price=1576.31, risk=0.0100, risk_amount=1000.07
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=3
# [OptimalF] Session: us, available trades: 3/20
# [OptimalF] (Default) session=us, equity=100001.67, price=1568.42, risk=0.0100, risk_amount=1000.02
# [OptimalF] Trade added: session=us, pnl=-1.73, total_trades=4
# [OptimalF] Session: asian, available trades: 3/20
# [OptimalF] (Default) session=asian, equity=100010.17, price=1563.80, risk=0.0100, risk_amount=1000.10
# [OptimalF] Trade added: session=asian, pnl=5.00, total_trades=4
# [OptimalF] Session: london, available trades: 4/20
# [OptimalF] (Default) session=london, equity=100002.29, price=1569.45, risk=0.0100, risk_amount=1000.02
# [OptimalF] Trade added: session=london, pnl=-0.61, total_trades=5
# [OptimalF] Session: us, available trades: 4/20
# [OptimalF] (Default) session=us, equity=99999.94, price=1565.54, risk=0.0100, risk_amount=1000.00
# [OptimalF] Trade added: session=us, pnl=3.99, total_trades=5
# [OptimalF] Session: asian, available trades: 4/20
# [OptimalF] (Default) session=asian, equity=100015.17, price=1593.90, risk=0.0100, risk_amount=1000.15
# [OptimalF] Trade added: session=asian, pnl=5.00, total_trades=5
# [OptimalF] Session: london, available trades: 5/20
# [OptimalF] (Default) session=london, equity=100001.69, price=1588.54, risk=0.0100, risk_amount=1000.02
# [OptimalF] Trade added: session=london, pnl=-5.00, total_trades=6
# [OptimalF] Session: london, available trades: 6/20
# [OptimalF] (Default) session=london, equity=99996.69, price=1580.60, risk=0.0100, risk_amount=999.97
# [OptimalF] Trade added: session=london, pnl=-5.00, total_trades=7
# [OptimalF] Session: london, available trades: 7/20
# [OptimalF] (Default) session=london, equity=99991.69, price=1572.69, risk=0.0100, risk_amount=999.92
# [OptimalF] Trade added: session=london, pnl=0.05, total_trades=8
# [OptimalF] Session: us, available trades: 5/20
# [OptimalF] (Default) session=us, equity=100003.92, price=1571.90, risk=0.0100, risk_amount=1000.04
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=6
# [OptimalF] Session: us, available trades: 6/20
# [OptimalF] (Default) session=us, equity=99998.92, price=1564.05, risk=0.0100, risk_amount=999.99
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=7
# [OptimalF] Session: us, available trades: 7/20
# [OptimalF] (Default) session=us, equity=99993.92, price=1556.23, risk=0.0100, risk_amount=999.94
# [OptimalF] Trade added: session=us, pnl=2.82, total_trades=8
# [OptimalF] Session: asian, available trades: 5/20
# [OptimalF] (Default) session=asian, equity=100020.17, price=1557.65, risk=0.0100, risk_amount=1000.20
# [OptimalF] Trade added: session=asian, pnl=5.00, total_trades=6
# [OptimalF] Session: london, available trades: 8/20
# [OptimalF] (Default) session=london, equity=99991.74, price=1546.22, risk=0.0100, risk_amount=999.92
# [OptimalF] Trade added: session=london, pnl=-5.00, total_trades=9
# [OptimalF] Session: london, available trades: 9/20
# [OptimalF] (Default) session=london, equity=99986.74, price=1553.95, risk=0.0100, risk_amount=999.87
# [OptimalF] Trade added: session=london, pnl=4.55, total_trades=10
# [OptimalF] Session: us, available trades: 8/20
# [OptimalF] (Default) session=us, equity=99996.75, price=1554.26, risk=0.0100, risk_amount=999.97
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=9
# [OptimalF] Session: asian, available trades: 6/20
# [OptimalF] (Default) session=asian, equity=100025.17, price=1552.38, risk=0.0100, risk_amount=1000.25
# [OptimalF] Trade added: session=asian, pnl=-0.59, total_trades=7
# [OptimalF] Session: london, available trades: 10/20
# [OptimalF] (Default) session=london, equity=99991.29, price=1551.45, risk=0.0100, risk_amount=999.91
# [OptimalF] Trade added: session=london, pnl=5.00, total_trades=11
# [OptimalF] Session: us, available trades: 9/20
# [OptimalF] (Default) session=us, equity=100001.75, price=1548.99, risk=0.0100, risk_amount=1000.02
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=10
# [OptimalF] Session: us, available trades: 10/20
# [OptimalF] (Default) session=us, equity=99996.75, price=1556.74, risk=0.0100, risk_amount=999.97
# [OptimalF] Trade added: session=us, pnl=-2.41, total_trades=11
# [OptimalF] Session: asian, available trades: 7/20
# [OptimalF] (Default) session=asian, equity=100024.58, price=1559.30, risk=0.0100, risk_amount=1000.25
# [OptimalF] Trade added: session=asian, pnl=4.09, total_trades=8
# [OptimalF] Session: london, available trades: 11/20
# [OptimalF] (Default) session=london, equity=99996.29, price=1552.91, risk=0.0100, risk_amount=999.96
# [OptimalF] Trade added: session=london, pnl=0.95, total_trades=12
# [OptimalF] Session: us, available trades: 11/20
# [OptimalF] (Default) session=us, equity=99994.33, price=1554.59, risk=0.0100, risk_amount=999.94
# [OptimalF] Trade added: session=us, pnl=3.64, total_trades=12
# [OptimalF] Session: asian, available trades: 8/20
# [OptimalF] (Default) session=asian, equity=100028.68, price=1544.35, risk=0.0100, risk_amount=1000.29
# [OptimalF] Trade added: session=asian, pnl=5.00, total_trades=9
# [OptimalF] Session: london, available trades: 12/20
# [OptimalF] (Default) session=london, equity=99997.23, price=1543.40, risk=0.0100, risk_amount=999.97
# [OptimalF] Trade added: session=london, pnl=0.04, total_trades=13
# [OptimalF] Session: us, available trades: 12/20
# [OptimalF] (Default) session=us, equity=99997.97, price=1542.49, risk=0.0100, risk_amount=999.98
# [OptimalF] Trade added: session=us, pnl=-2.83, total_trades=13
# [OptimalF] Session: asian, available trades: 9/20
# [OptimalF] (Default) session=asian, equity=100033.68, price=1549.16, risk=0.0100, risk_amount=1000.34
# [OptimalF] Trade added: session=asian, pnl=2.42, total_trades=10
# [OptimalF] Session: london, available trades: 13/20
# [OptimalF] (Default) session=london, equity=99997.27, price=1552.90, risk=0.0100, risk_amount=999.97
# [OptimalF] Trade added: session=london, pnl=-2.60, total_trades=14
# [OptimalF] Session: us, available trades: 13/20
# [OptimalF] (Default) session=us, equity=99995.15, price=1550.56, risk=0.0100, risk_amount=999.95
# [OptimalF] Trade added: session=us, pnl=3.76, total_trades=14
# [OptimalF] Session: asian, available trades: 10/20
# [OptimalF] (Default) session=asian, equity=100036.09, price=1556.44, risk=0.0100, risk_amount=1000.36
# [OptimalF] Trade added: session=asian, pnl=-2.19, total_trades=11
# [OptimalF] Session: london, available trades: 14/20
# [OptimalF] (Default) session=london, equity=99994.68, price=1553.04, risk=0.0100, risk_amount=999.95
# [OptimalF] Trade added: session=london, pnl=-1.46, total_trades=15
# [OptimalF] Session: us, available trades: 14/20
# [OptimalF] (Default) session=us, equity=99998.91, price=1556.07, risk=0.0100, risk_amount=999.99
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=15
# [OptimalF] Session: asian, available trades: 11/20
# [OptimalF] (Default) session=asian, equity=100033.90, price=1552.10, risk=0.0100, risk_amount=1000.34
# [OptimalF] Trade added: session=asian, pnl=-2.19, total_trades=12
# [OptimalF] Session: london, available trades: 15/20
# [OptimalF] (Default) session=london, equity=99993.22, price=1555.49, risk=0.0100, risk_amount=999.93
# [OptimalF] Trade added: session=london, pnl=0.33, total_trades=16
# [OptimalF] Session: us, available trades: 15/20
# [OptimalF] (Default) session=us, equity=100003.91, price=1558.93, risk=0.0100, risk_amount=1000.04
# [OptimalF] Trade added: session=us, pnl=-1.30, total_trades=16
# [OptimalF] Session: asian, available trades: 12/20
# [OptimalF] (Default) session=asian, equity=100031.71, price=1557.22, risk=0.0100, risk_amount=1000.32
# [OptimalF] Trade added: session=asian, pnl=2.75, total_trades=13
# [OptimalF] Session: london, available trades: 16/20
# [OptimalF] (Default) session=london, equity=99993.55, price=1561.50, risk=0.0100, risk_amount=999.94
# [OptimalF] Trade added: session=london, pnl=-0.49, total_trades=17
# [OptimalF] Session: us, available trades: 16/20
# [OptimalF] (Default) session=us, equity=100002.61, price=1558.77, risk=0.0100, risk_amount=1000.03
# [OptimalF] Trade added: session=us, pnl=1.10, total_trades=17
# [OptimalF] Session: asian, available trades: 13/20
# [OptimalF] (Default) session=asian, equity=100034.46, price=1561.26, risk=0.0100, risk_amount=1000.34
# [OptimalF] Trade added: session=asian, pnl=0.77, total_trades=14
# [OptimalF] Session: london, available trades: 17/20
# [OptimalF] (Default) session=london, equity=99993.07, price=1560.06, risk=0.0100, risk_amount=999.93
# [OptimalF] Trade added: session=london, pnl=5.00, total_trades=18
# [OptimalF] Session: us, available trades: 17/20
# [OptimalF] (Default) session=us, equity=100003.71, price=1556.02, risk=0.0100, risk_amount=1000.04
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=18
# [OptimalF] Session: asian, available trades: 14/20
# [OptimalF] (Default) session=asian, equity=100035.23, price=1556.38, risk=0.0100, risk_amount=1000.35
# [OptimalF] Trade added: session=asian, pnl=1.36, total_trades=15
# [OptimalF] Session: london, available trades: 18/20
# [OptimalF] (Default) session=london, equity=99998.07, price=1554.26, risk=0.0100, risk_amount=999.98
# [OptimalF] Trade added: session=london, pnl=-1.86, total_trades=19
# [OptimalF] Session: us, available trades: 18/20
# [OptimalF] (Default) session=us, equity=100008.71, price=1555.33, risk=0.0100, risk_amount=1000.09
# [OptimalF] Trade added: session=us, pnl=-2.29, total_trades=19
# [OptimalF] Session: asian, available trades: 15/20
# [OptimalF] (Default) session=asian, equity=100036.59, price=1561.18, risk=0.0100, risk_amount=1000.37
# [OptimalF] Trade added: session=asian, pnl=-5.00, total_trades=16
# [OptimalF] Session: asian, available trades: 16/20
# [OptimalF] (Default) session=asian, equity=100031.59, price=1553.38, risk=0.0100, risk_amount=1000.32
# [OptimalF] Trade added: session=asian, pnl=0.38, total_trades=17
# [OptimalF] Session: london, available trades: 19/20
# [OptimalF] (Default) session=london, equity=99996.21, price=1553.96, risk=0.0100, risk_amount=999.96
# [OptimalF] Trade added: session=london, pnl=-5.00, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99991.21, optimal_f=0.0100, risk_amount=999.91
# [OptimalF] Trade added: session=london, pnl=-0.40, total_trades=20
# [OptimalF] Session: us, available trades: 19/20
# [OptimalF] (Default) session=us, equity=100006.42, price=1555.09, risk=0.0100, risk_amount=1000.06
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'us' = 0.0200
# [OptimalF] (Optimal) session=us, equity=100001.41, optimal_f=0.0200, risk_amount=2000.03
# [OptimalF] Trade added: session=us, pnl=0.52, total_trades=20
# [OptimalF] Session: asian, available trades: 17/20
# [OptimalF] (Default) session=asian, equity=100031.97, price=1560.58, risk=0.0100, risk_amount=1000.32
# [OptimalF] Trade added: session=asian, pnl=-0.53, total_trades=18
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99990.81, optimal_f=0.0100, risk_amount=999.91
# [OptimalF] Trade added: session=london, pnl=-5.00, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99985.81, optimal_f=0.0100, risk_amount=999.86
# [OptimalF] Trade added: session=london, pnl=-5.00, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99980.81, optimal_f=0.0100, risk_amount=999.81
# [OptimalF] Trade added: session=london, pnl=3.37, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=100001.94, optimal_f=0.0100, risk_amount=1000.02
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99996.94, optimal_f=0.0100, risk_amount=999.97
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99991.94, optimal_f=0.0100, risk_amount=999.92
# [OptimalF] Trade added: session=us, pnl=1.21, total_trades=20
# [OptimalF] Session: asian, available trades: 18/20
# [OptimalF] (Default) session=asian, equity=100031.44, price=1582.17, risk=0.0100, risk_amount=1000.31
# [OptimalF] Trade added: session=asian, pnl=-2.50, total_trades=19
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99984.18, optimal_f=0.0100, risk_amount=999.84
# [OptimalF] Trade added: session=london, pnl=5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99993.15, optimal_f=0.0100, risk_amount=999.93
# [OptimalF] Trade added: session=us, pnl=-0.48, total_trades=20
# [OptimalF] Session: asian, available trades: 19/20
# [OptimalF] (Default) session=asian, equity=100028.94, price=1581.10, risk=0.0100, risk_amount=1000.29
# [OptimalF] Trade added: session=asian, pnl=-1.93, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99989.18, optimal_f=0.0100, risk_amount=999.89
# [OptimalF] Trade added: session=london, pnl=5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99992.67, optimal_f=0.0100, risk_amount=999.93
# [OptimalF] Trade added: session=us, pnl=3.33, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'asian' = 0.6400
# [OptimalF] (Optimal) session=asian, equity=100027.01, optimal_f=0.6400, risk_amount=64017.29
# [OptimalF] Trade added: session=asian, pnl=-31.84, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99994.18, optimal_f=0.0100, risk_amount=999.94
# [OptimalF] Trade added: session=london, pnl=-0.53, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99995.99, optimal_f=0.0100, risk_amount=999.96
# [OptimalF] Trade added: session=us, pnl=3.91, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99995.16, optimal_f=0.0100, risk_amount=999.95
# [OptimalF] Trade added: session=asian, pnl=3.09, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'london' = 0.0400
# [OptimalF] (Optimal) session=london, equity=99993.65, optimal_f=0.0400, risk_amount=3999.75
# [OptimalF] Trade added: session=london, pnl=-20.00, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99973.65, optimal_f=0.0100, risk_amount=999.74
# [OptimalF] Trade added: session=london, pnl=6.53, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'us' = 0.1100
# [OptimalF] (Optimal) session=us, equity=99999.91, optimal_f=0.1100, risk_amount=10999.99
# [OptimalF] Trade added: session=us, pnl=-55.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99944.91, optimal_f=0.0100, risk_amount=999.45
# [OptimalF] Trade added: session=us, pnl=2.67, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99998.25, optimal_f=0.0100, risk_amount=999.98
# [OptimalF] Trade added: session=asian, pnl=-1.33, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99980.18, optimal_f=0.0100, risk_amount=999.80
# [OptimalF] Trade added: session=london, pnl=-5.00, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99975.18, optimal_f=0.0100, risk_amount=999.75
# [OptimalF] Trade added: session=london, pnl=-1.92, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99947.58, optimal_f=0.0100, risk_amount=999.48
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99996.92, optimal_f=0.0100, risk_amount=999.97
# [OptimalF] Trade added: session=asian, pnl=-5.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99991.92, optimal_f=0.0100, risk_amount=999.92
# [OptimalF] Trade added: session=asian, pnl=-3.76, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99973.26, optimal_f=0.0100, risk_amount=999.73
# [OptimalF] Trade added: session=london, pnl=0.52, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99952.58, optimal_f=0.0100, risk_amount=999.53
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99988.16, optimal_f=0.0100, risk_amount=999.88
# [OptimalF] Trade added: session=asian, pnl=-5.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99983.16, optimal_f=0.0100, risk_amount=999.83
# [OptimalF] Trade added: session=asian, pnl=1.36, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99973.78, optimal_f=0.0100, risk_amount=999.74
# [OptimalF] Trade added: session=london, pnl=5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99957.58, optimal_f=0.0100, risk_amount=999.58
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99984.52, optimal_f=0.0100, risk_amount=999.85
# [OptimalF] Trade added: session=asian, pnl=-5.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99979.52, optimal_f=0.0100, risk_amount=999.80
# [OptimalF] Trade added: session=asian, pnl=-0.14, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99978.78, optimal_f=0.0100, risk_amount=999.79
# [OptimalF] Trade added: session=london, pnl=-5.00, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99973.78, optimal_f=0.0100, risk_amount=999.74
# [OptimalF] Trade added: session=london, pnl=2.06, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99962.58, optimal_f=0.0100, risk_amount=999.63
# [OptimalF] Trade added: session=us, pnl=-1.42, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99979.38, optimal_f=0.0100, risk_amount=999.79
# [OptimalF] Trade added: session=asian, pnl=-1.79, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99975.84, optimal_f=0.0100, risk_amount=999.76
# [OptimalF] Trade added: session=london, pnl=5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99961.16, optimal_f=0.0100, risk_amount=999.61
# [OptimalF] Trade added: session=us, pnl=-0.24, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99977.59, optimal_f=0.0100, risk_amount=999.78
# [OptimalF] Trade added: session=asian, pnl=0.76, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99980.84, optimal_f=0.0100, risk_amount=999.81
# [OptimalF] Trade added: session=london, pnl=0.13, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99960.92, optimal_f=0.0100, risk_amount=999.61
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99955.92, optimal_f=0.0100, risk_amount=999.56
# [OptimalF] Trade added: session=us, pnl=1.84, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99978.34, optimal_f=0.0100, risk_amount=999.78
# [OptimalF] Trade added: session=asian, pnl=-1.50, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99980.98, optimal_f=0.0100, risk_amount=999.81
# [OptimalF] Trade added: session=london, pnl=1.02, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99957.76, optimal_f=0.0100, risk_amount=999.58
# [OptimalF] Trade added: session=us, pnl=0.62, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99976.85, optimal_f=0.0100, risk_amount=999.77
# [OptimalF] Trade added: session=asian, pnl=-2.73, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99981.99, optimal_f=0.0100, risk_amount=999.82
# [OptimalF] Trade added: session=london, pnl=2.63, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99958.39, optimal_f=0.0100, risk_amount=999.58
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99974.11, optimal_f=0.0100, risk_amount=999.74
# [OptimalF] Trade added: session=asian, pnl=1.01, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99984.63, optimal_f=0.0100, risk_amount=999.85
# [OptimalF] Trade added: session=london, pnl=1.44, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99963.38, optimal_f=0.0100, risk_amount=999.63
# [OptimalF] Trade added: session=us, pnl=-0.45, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99975.12, optimal_f=0.0100, risk_amount=999.75
# [OptimalF] Trade added: session=asian, pnl=3.22, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99986.06, optimal_f=0.0100, risk_amount=999.86
# [OptimalF] Trade added: session=london, pnl=0.89, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99962.94, optimal_f=0.0100, risk_amount=999.63
# [OptimalF] Trade added: session=us, pnl=2.10, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99978.34, optimal_f=0.0100, risk_amount=999.78
# [OptimalF] Trade added: session=asian, pnl=-1.22, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99986.95, optimal_f=0.0100, risk_amount=999.87
# [OptimalF] Trade added: session=london, pnl=-4.37, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99965.04, optimal_f=0.0100, risk_amount=999.65
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99960.04, optimal_f=0.0100, risk_amount=999.60
# [OptimalF] Trade added: session=us, pnl=0.48, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99977.12, optimal_f=0.0100, risk_amount=999.77
# [OptimalF] Trade added: session=asian, pnl=1.92, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=99982.58, optimal_f=0.0100, risk_amount=999.83
# [OptimalF] Trade added: session=london, pnl=-0.80, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99960.52, optimal_f=0.0100, risk_amount=999.61
# [OptimalF] Trade added: session=us, pnl=0.32, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99979.03, optimal_f=0.0100, risk_amount=999.79
# [OptimalF] Trade added: session=asian, pnl=2.32, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.0300
# [OptimalF] (Optimal) session=london, equity=99981.78, optimal_f=0.0300, risk_amount=2999.45
# [OptimalF] Trade added: session=london, pnl=15.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99960.83, optimal_f=0.0100, risk_amount=999.61
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99981.35, optimal_f=0.0100, risk_amount=999.81
# [OptimalF] Trade added: session=asian, pnl=2.85, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.2600
# [OptimalF] (Optimal) session=london, equity=99996.77, optimal_f=0.2600, risk_amount=25999.16
# [OptimalF] Trade added: session=london, pnl=22.72, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99965.83, optimal_f=0.0100, risk_amount=999.66
# [OptimalF] Trade added: session=us, pnl=2.96, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99984.21, optimal_f=0.0100, risk_amount=999.84
# [OptimalF] Trade added: session=asian, pnl=-1.34, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.4300
# [OptimalF] (Optimal) session=london, equity=100019.50, optimal_f=0.4300, risk_amount=43008.38
# [OptimalF] Trade added: session=london, pnl=215.04, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99968.79, optimal_f=0.0100, risk_amount=999.69
# [OptimalF] Trade added: session=us, pnl=1.16, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -31.84
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99982.87, optimal_f=0.0100, risk_amount=999.83
# [OptimalF] Trade added: session=asian, pnl=5.00, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.6300
# [OptimalF] (Optimal) session=london, equity=100234.54, optimal_f=0.6300, risk_amount=63147.76
# [OptimalF] Trade added: session=london, pnl=315.74, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99969.94, optimal_f=0.0100, risk_amount=999.70
# [OptimalF] Trade added: session=us, pnl=5.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99987.86, optimal_f=0.0100, risk_amount=999.88
# [OptimalF] Trade added: session=asian, pnl=5.00, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -20.00
# [OptimalF] Best f for session 'london' = 0.7300
# [OptimalF] (Optimal) session=london, equity=100550.28, optimal_f=0.7300, risk_amount=73401.70
# [OptimalF] Trade added: session=london, pnl=367.01, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -55.00
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99974.94, optimal_f=0.0100, risk_amount=999.75
# [OptimalF] Trade added: session=us, pnl=-5.00, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'us' = 0.4700
# [OptimalF] (Optimal) session=us, equity=99969.94, optimal_f=0.4700, risk_amount=46985.87
# [OptimalF] Trade added: session=us, pnl=-234.93, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -234.93
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99735.02, optimal_f=0.0100, risk_amount=997.35
# [OptimalF] Trade added: session=us, pnl=-4.99, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99992.86, optimal_f=0.0100, risk_amount=999.93
# [OptimalF] Trade added: session=asian, pnl=5.00, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'london' = 0.7000
# [OptimalF] (Optimal) session=london, equity=100917.29, optimal_f=0.7000, risk_amount=70642.10
# [OptimalF] Trade added: session=london, pnl=-353.21, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -353.21
# [OptimalF] Best f for session 'london' = 0.4700
# [OptimalF] (Optimal) session=london, equity=100564.08, optimal_f=0.4700, risk_amount=47265.12
# [OptimalF] Trade added: session=london, pnl=-236.33, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -353.21
# [OptimalF] Best f for session 'london' = 0.2700
# [OptimalF] (Optimal) session=london, equity=100327.75, optimal_f=0.2700, risk_amount=27088.49
# [OptimalF] Trade added: session=london, pnl=47.53, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -234.93
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99730.03, optimal_f=0.0100, risk_amount=997.30
# [OptimalF] Trade added: session=us, pnl=-4.99, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -234.93
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99725.04, optimal_f=0.0100, risk_amount=997.25
# [OptimalF] Trade added: session=us, pnl=9.97, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.00
# [OptimalF] Best f for session 'asian' = 0.0200
# [OptimalF] (Optimal) session=asian, equity=99997.86, optimal_f=0.0200, risk_amount=1999.96
# [OptimalF] Trade added: session=asian, pnl=-10.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -10.00
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99987.86, optimal_f=0.0100, risk_amount=999.88
# [OptimalF] Trade added: session=asian, pnl=2.18, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -353.21
# [OptimalF] Best f for session 'london' = 0.3000
# [OptimalF] (Optimal) session=london, equity=100375.28, optimal_f=0.3000, risk_amount=30112.58
# [OptimalF] Trade added: session=london, pnl=-150.56, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -353.21
# [OptimalF] Best f for session 'london' = 0.1800
# [OptimalF] (Optimal) session=london, equity=100224.72, optimal_f=0.1800, risk_amount=18040.45
# [OptimalF] Trade added: session=london, pnl=180.40, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -234.93
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99735.01, optimal_f=0.0100, risk_amount=997.35
# [OptimalF] Trade added: session=us, pnl=-4.99, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -234.93
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99730.03, optimal_f=0.0100, risk_amount=997.30
# [OptimalF] Trade added: session=us, pnl=-4.99, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -234.93
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99725.04, optimal_f=0.0100, risk_amount=997.25
# [OptimalF] Trade added: session=us, pnl=6.56, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -10.00
# [OptimalF] Best f for session 'asian' = 0.0700
# [OptimalF] (Optimal) session=asian, equity=99990.05, optimal_f=0.0700, risk_amount=6999.30
# [OptimalF] Trade added: session=asian, pnl=-35.00, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -35.00
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99955.05, optimal_f=0.0100, risk_amount=999.55
# [OptimalF] Trade added: session=asian, pnl=2.58, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -353.21
# [OptimalF] Best f for session 'london' = 0.2900
# [OptimalF] (Optimal) session=london, equity=100405.12, optimal_f=0.2900, risk_amount=29117.49
# [OptimalF] Trade added: session=london, pnl=145.59, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -234.93
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99731.60, optimal_f=0.0100, risk_amount=997.32
# [OptimalF] Trade added: session=us, pnl=-4.99, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -234.93
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=99726.61, optimal_f=0.0100, risk_amount=997.27
# [OptimalF] Trade added: session=us, pnl=-4.99, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# ...
# [OptimalF] Trade added: session=london, pnl=-5.11, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -32.32
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102120.66, optimal_f=0.0100, risk_amount=1021.21
# [OptimalF] Trade added: session=london, pnl=4.52, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -146.86
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97777.68, optimal_f=0.0100, risk_amount=977.78
# [OptimalF] Trade added: session=us, pnl=4.89, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -74.52
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99269.77, optimal_f=0.0100, risk_amount=992.70
# [OptimalF] Trade added: session=asian, pnl=-4.96, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -74.52
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99264.81, optimal_f=0.0100, risk_amount=992.65
# [OptimalF] Trade added: session=asian, pnl=2.35, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -32.32
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102125.18, optimal_f=0.0100, risk_amount=1021.25
# [OptimalF] Trade added: session=london, pnl=5.11, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -4.89
# [OptimalF] Best f for session 'us' = 0.3600
# [OptimalF] (Optimal) session=us, equity=97782.57, optimal_f=0.3600, risk_amount=35201.73
# [OptimalF] Trade added: session=us, pnl=-176.01, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97606.56, optimal_f=0.0100, risk_amount=976.07
# [OptimalF] Trade added: session=us, pnl=-4.88, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97601.68, optimal_f=0.0100, risk_amount=976.02
# [OptimalF] Trade added: session=us, pnl=-3.46, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -4.96
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99267.15, optimal_f=0.0100, risk_amount=992.67
# [OptimalF] Trade added: session=asian, pnl=4.96, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -32.32
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102130.29, optimal_f=0.0100, risk_amount=1021.30
# [OptimalF] Trade added: session=london, pnl=5.11, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97598.22, optimal_f=0.0100, risk_amount=975.98
# [OptimalF] Trade added: session=us, pnl=-4.88, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97593.34, optimal_f=0.0100, risk_amount=975.93
# [OptimalF] Trade added: session=us, pnl=-4.88, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97588.46, optimal_f=0.0100, risk_amount=975.88
# [OptimalF] Trade added: session=us, pnl=3.32, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -4.96
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99272.11, optimal_f=0.0100, risk_amount=992.72
# [OptimalF] Trade added: session=asian, pnl=-0.56, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -32.32
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102135.39, optimal_f=0.0100, risk_amount=1021.35
# [OptimalF] Trade added: session=london, pnl=-1.96, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97591.78, optimal_f=0.0100, risk_amount=975.92
# [OptimalF] Trade added: session=us, pnl=-2.78, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -4.96
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99271.56, optimal_f=0.0100, risk_amount=992.72
# [OptimalF] Trade added: session=asian, pnl=4.96, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -32.32
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102133.44, optimal_f=0.0100, risk_amount=1021.33
# [OptimalF] Trade added: session=london, pnl=5.11, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97589.00, optimal_f=0.0100, risk_amount=975.89
# [OptimalF] Trade added: session=us, pnl=4.88, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -4.96
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99276.52, optimal_f=0.0100, risk_amount=992.77
# [OptimalF] Trade added: session=asian, pnl=4.96, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -32.32
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102138.54, optimal_f=0.0100, risk_amount=1021.39
# [OptimalF] Trade added: session=london, pnl=5.11, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97593.88, optimal_f=0.0100, risk_amount=975.94
# [OptimalF] Trade added: session=us, pnl=-4.88, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97589.00, optimal_f=0.0100, risk_amount=975.89
# [OptimalF] Trade added: session=us, pnl=2.66, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -4.96
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99281.48, optimal_f=0.0100, risk_amount=992.81
# [OptimalF] Trade added: session=asian, pnl=-4.96, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -4.96
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99276.52, optimal_f=0.0100, risk_amount=992.77
# [OptimalF] Trade added: session=asian, pnl=-0.21, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -32.32
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102143.65, optimal_f=0.0100, risk_amount=1021.44
# [OptimalF] Trade added: session=london, pnl=-5.11, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -32.32
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102138.54, optimal_f=0.0100, risk_amount=1021.39
# [OptimalF] Trade added: session=london, pnl=-5.11, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -32.32
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102133.44, optimal_f=0.0100, risk_amount=1021.33
# [OptimalF] Trade added: session=london, pnl=-0.21, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97591.66, optimal_f=0.0100, risk_amount=975.92
# [OptimalF] Trade added: session=us, pnl=-4.88, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97586.78, optimal_f=0.0100, risk_amount=975.87
# [OptimalF] Trade added: session=us, pnl=-1.44, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -4.96
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99276.31, optimal_f=0.0100, risk_amount=992.76
# [OptimalF] Trade added: session=asian, pnl=4.33, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.11
# [OptimalF] Best f for session 'london' = 0.0100
# [OptimalF] (Optimal) session=london, equity=102133.23, optimal_f=0.0100, risk_amount=1021.33
# [OptimalF] Trade added: session=london, pnl=1.40, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97585.34, optimal_f=0.0100, risk_amount=975.85
# [OptimalF] Trade added: session=us, pnl=3.84, total_trades=20
# [OptimalF] Session: asian, available trades: 20/20
# [OptimalF] Computing f for session 'asian'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -4.96
# [OptimalF] Best f for session 'asian' = 0.0100
# [OptimalF] (Optimal) session=asian, equity=99280.64, optimal_f=0.0100, risk_amount=992.81
# [OptimalF] Trade added: session=asian, pnl=4.96, total_trades=20
# [OptimalF] Session: london, available trades: 20/20
# [OptimalF] Computing f for session 'london'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -5.11
# [OptimalF] Best f for session 'london' = 0.0400
# [OptimalF] (Optimal) session=london, equity=102134.62, optimal_f=0.0400, risk_amount=4085.38
# [OptimalF] Trade added: session=london, pnl=8.63, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97589.18, optimal_f=0.0100, risk_amount=975.89
# [OptimalF] Trade added: session=us, pnl=-4.88, total_trades=20
# [OptimalF] Session: us, available trades: 20/20
# [OptimalF] Computing f for session 'us'
#   ↳ Rolling window size: 20
#   ↳ Biggest loss in window: -176.01
# [OptimalF] Best f for session 'us' = 0.0100
# [OptimalF] (Optimal) session=us, equity=97584.30, optimal_f=0.0100, risk_amount=975.84
# [OptimalF] Trade added: session=us, pnl=6.25, total_trades=20
# 2025-05-12 16:33:26,761 - INFO - Exported detailed trades to data/results/trades_detailed_XAUUSD_optimal_f.csv
# 2025-05-12 16:33:26,829 - INFO - Saved backtest results to data/results/backtest_results_XAUUSD_optimal_f.txt
# === XAUUSD Backtest Results ===
# Bet Sizing Strategy: optimalf
#
# Period: 2020-01-02 to 2024-11-22
#
# ASIAN Session Performance:
# Initial Capital: $100,000.00
# Final Capital: $99,285.60
# Total PnL: $-714.40
# Return: -0.71%
# Win Rate: 49.51% (759W/774L)
# Max Drawdown: 2.26%
# Sharpe Ratio: -0.15
# Skewness: 0.179
# Excess Kurtosis: 30.040
#
# Attempt Analysis:
#
#   Attempt 1:
#   Trades: 1277 (83.3% of session trades)
#   PnL: $-1,036.89
#   Win Rate: 49.10% (627W/650L)
#   Average Win: $16.73
#   Average Loss: $-18.07
#
#   Attempt 2:
#   Trades: 217 (14.2% of session trades)
#   PnL: $341.52
#   Win Rate: 53.00% (115W/102L)
#   Average Win: $6.31
#   Average Loss: $-3.76
#
#   Attempt 3:
#   Trades: 39 (2.5% of session trades)
#   PnL: $-19.04
#   Win Rate: 43.59% (17W/22L)
#   Average Win: $3.08
#   Average Loss: $-3.25
#
# LONDON Session Performance:
# Initial Capital: $100,000.00
# Final Capital: $102,143.26
# Total PnL: $2,143.26
# Return: 2.14%
# Win Rate: 49.46% (920W/940L)
# Max Drawdown: 2.30%
# Sharpe Ratio: 0.26
# Skewness: 0.141
# Excess Kurtosis: 10.696
#
# Attempt Analysis:
#
#   Attempt 1:
#   Trades: 1277 (68.7% of session trades)
#   PnL: $1,096.73
#   Win Rate: 50.43% (644W/633L)
#   Average Win: $33.79
#   Average Loss: $-33.27
#
#   Attempt 2:
#   Trades: 450 (24.2% of session trades)
#   PnL: $1,481.07
#   Win Rate: 47.56% (214W/236L)
#   Average Win: $23.18
#   Average Loss: $-14.75
#
#   Attempt 3:
#   Trades: 133 (7.2% of session trades)
#   PnL: $-434.55
#   Win Rate: 46.62% (62W/71L)
#   Average Win: $7.32
#   Average Loss: $-12.51
#
# US Session Performance:
# Initial Capital: $100,000.00
# Final Capital: $97,590.55
# Total PnL: $-2,409.45
# Return: -2.41%
# Win Rate: 50.33% (920W/908L)
# Max Drawdown: 2.54%
# Sharpe Ratio: -0.38
# Skewness: -0.957
# Excess Kurtosis: 17.654
#
# Attempt Analysis:
#
#   Attempt 1:
#   Trades: 1277 (69.9% of session trades)
#   PnL: $-1,234.12
#   Win Rate: 52.39% (669W/608L)
#   Average Win: $21.66
#   Average Loss: $-26.39
#
#   Attempt 2:
#   Trades: 414 (22.6% of session trades)
#   PnL: $-991.36
#   Win Rate: 44.93% (186W/228L)
#   Average Win: $7.99
#   Average Loss: $-10.87
#
#   Attempt 3:
#   Trades: 137 (7.5% of session trades)
#   PnL: $-183.97
#   Win Rate: 47.45% (65W/72L)
#   Average Win: $5.93
#   Average Loss: $-7.91
# [OptimalF] Statistics:
#   - Total trades seen: 5221
#   - Valid trades used: 5221
#   - Skipped trades: 0
#   - Available cash cap was hit 0 times
#   - Session 'asian': 20 trades, optimal_f=0.0100
#   - Session 'london': 20 trades, optimal_f=0.0400
#   - Session 'us': 20 trades, optimal_f=0.0100
# [INFO] PercentVolatilityBetSizing limit hit 0 times.
